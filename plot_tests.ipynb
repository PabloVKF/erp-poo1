# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from data_manager import DataManager

# %%
data_manager = DataManager()
df_produto : pd.DataFrame = data_manager.dataframe_dict["produtos"]
df_produto.head()
# Out:
#    id  produto fornecedor
# 0   1     Faca      Havan
# 1   2    Mouse      Apple
# 2  10    Mouse  Microsoft
# 3   3  Celular    Samsung
# 4  11  Celular      Apple

# %%
sns.displot(df_produto["fornecedor"])

# %%
sns.jointplot(x="produto", y="fornecedor", data=df_produto)

# %%
sns.scatterplot(x="produto", y="fornecedor", data=df_produto).set_title("Forecedores X Produtos")
# Out:
# Text(0.5, 1.0, 'Forecedores X Produtos')
