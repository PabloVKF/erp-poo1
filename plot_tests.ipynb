# %%
import matplotlib.pyplot as plt
import seaborn as sns
from data_manager import DataManager
# Out:
# <class 'list'>

# %%
data = DataManager().data
data.head()
# Out:
#    id   produto   fornecedor  preco_compra  preco_venda
# 0   0  produto0  fornecedor0           7.0         12.6
# 1   1  produto1  fornecedor1           2.0          3.6
# 2   2  produto2  fornecedor2           3.0          5.4
# 3   3  produto3  fornecedor3           9.0         16.2
# 4   4  produto4  fornecedor4          14.0         25.2

# %%
data["produto"].head()
# Out:
# 0    produto0
# 1    produto1
# 2    produto2
# 3    produto3
# 4    produto4
# Name: produto, dtype: object

# %%
sns.displot(data["produto"])

# %%
sns.jointplot(x="produto", y="fornecedor", data=data)

# %%
sns.pairplot(data)

# %%
sns.scatterplot(x="produto", y="fornecedor", data=data).set_title("Forecedores X Produtos")
# Out:
# Text(0.5, 1.0, 'Forecedores X Produtos')
